# %%
# 引入 keras 套件
import keras
# 手寫辨識
from keras.datasets import mnist
# 使用 Sequential 序貫模型
from keras.models import Sequential
# 使用核心網路層
from keras.layers import Dense, Dropout, LeakyReLU, Conv2D
# 優化器 Optimizers
from keras.optimizers import RMSprop
# 後端Backend
from keras import backend as K
# 讀取並顯示圖片方法
from matplotlib.pyplot import imshow
# 引入 numpy 模組
import numpy as np


(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes = 10

x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Sequential順序模型
model = Sequential()
# 將layer加入模型中
model.add(Dense(20, activation=LeakyReLU(), input_shape=(784,)))
model.add(Dense(20, activation=LeakyReLU()))
model.add(Dense(10, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    # 以128個樣本為一個batch
                    batch_size=128,
                    # 訓練次數
                    epochs=10,
                    verbose=1,
                    validation_data=(x_test, y_test))

scores = model.evaluate(x_test, y_test)
print(scores[1])
# Out:
# Using TensorFlow backend.
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 1s 0us/step
# 60000 train samples
# 10000 test samples
# /usr/local/lib/python3.6/dist-packages/keras/activations.py:235: UserWarning: Do not pass a layer instance (such as LeakyReLU) as the activation argument of another layer. Instead, advanced activation layers should be used just like any other layer in a model.
#   identifier=identifier.__class__.__name__))
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 20)                15700
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                210
# =================================================================
# Total params: 16,330
# Trainable params: 16,330
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 52us/step - loss: 0.5173 - accuracy: 0.8588 - val_loss: 0.2876 - val_accuracy: 0.9182
# Epoch 2/10
# 60000/60000 [==============================] - 1s 23us/step - loss: 0.2724 - accuracy: 0.9216 - val_loss: 0.2540 - val_accuracy: 0.9259
# Epoch 3/10
# 60000/60000 [==============================] - 2s 25us/step - loss: 0.2410 - accuracy: 0.9302 - val_loss: 0.2286 - val_accuracy: 0.9331
# Epoch 4/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.2181 - accuracy: 0.9372 - val_loss: 0.2131 - val_accuracy: 0.9379
# Epoch 5/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1992 - accuracy: 0.9432 - val_loss: 0.1988 - val_accuracy: 0.9416
# Epoch 6/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1836 - accuracy: 0.9471 - val_loss: 0.1954 - val_accuracy: 0.9425
# Epoch 7/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1706 - accuracy: 0.9513 - val_loss: 0.1878 - val_accuracy: 0.9462
# Epoch 8/10
# 60000/60000 [==============================] - 1s 24us/step - loss: 0.1609 - accuracy: 0.9531 - val_loss: 0.1713 - val_accuracy: 0.9503
# Epoch 9/10
# 60000/60000 [==============================] - 2s 25us/step - loss: 0.1526 - accuracy: 0.9556 - val_loss: 0.1753 - val_accuracy: 0.9484
# Epoch 10/10
# 60000/60000 [==============================] - 2s 25us/step - loss: 0.1457 - accuracy: 0.9579 - val_loss: 0.1646 - val_accuracy: 0.9528
# 10000/10000 [==============================] - 1s 50us/step
# 0.9527999758720398
