# %%
# 引入 keras 套件
import keras
# 使用 Sequential 序貫模型
from keras.models import Sequential
from keras.layers import Dense
# 引入 numpy 模組
import numpy as np
data = np.random.random((1000, 10)) #隨機產生1000筆資料，每筆資料1包含十個float數字
labels = np.random.randint(2, size=(1000, 1)) #隨機產生1000筆資料，每筆資料上限為2(意思就是0 或 1)
print(np.shape(data))
print(data[0])
print(np.shape(labels))
print(labels[0])
# Sequential順序模型
model = Sequential()
# 將layer加入模型中
model.add(Dense(32, activation='relu', input_dim=10))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(data, labels, epochs=10, batch_size=32)

score=model.evaluate(data, labels)
print(score[1])
# Out:
# Using TensorFlow backend.
# (1000, 10)
# [0.80551361 0.69993483 0.36883174 0.10631213 0.89697847 0.64531234
#  0.60916097 0.82101451 0.83521823 0.66859838]
# (1000, 1)
# [1]
# Epoch 1/10
# 1000/1000 [==============================] - 2s 2ms/step - loss: 0.7028 - accuracy: 0.5050
# Epoch 2/10
# 1000/1000 [==============================] - 0s 69us/step - loss: 0.6970 - accuracy: 0.5270
# Epoch 3/10
# 1000/1000 [==============================] - 0s 69us/step - loss: 0.6946 - accuracy: 0.5250
# Epoch 4/10
# 1000/1000 [==============================] - 0s 78us/step - loss: 0.6950 - accuracy: 0.5160
# Epoch 5/10
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.6942 - accuracy: 0.5220
# Epoch 6/10
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.6928 - accuracy: 0.5290
# Epoch 7/10
# 1000/1000 [==============================] - 0s 69us/step - loss: 0.6925 - accuracy: 0.5300
# Epoch 8/10
# 1000/1000 [==============================] - 0s 69us/step - loss: 0.6919 - accuracy: 0.5310
# Epoch 9/10
# 1000/1000 [==============================] - 0s 73us/step - loss: 0.6914 - accuracy: 0.5390
# Epoch 10/10
# 1000/1000 [==============================] - 0s 76us/step - loss: 0.6906 - accuracy: 0.5350
# 1000/1000 [==============================] - 0s 56us/step
# 0.5529999732971191
